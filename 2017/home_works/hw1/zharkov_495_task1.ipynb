# %% [markdown]
# <span style="font-size: 14pt">MIPT, Advanced ML, Autumn 2017</span>
#
# <span style="font-size: 16pt"> HW#1 </span>
#
# <span style="color:blue; font-size: 12pt">Alexey Romanenko </span>,
# <span style="color:blue; font-size: 12pt; font-family: 'Verdana'">alexromsput@gmail.com</span>

# %% [markdown]
# <h1 align="center">Organization Info</h1>

# %% [markdown]
# **Дополнительный материал для выполнения дз**:
# - Лукишн Ю.П. Адаптивные методы краткосрочного прогнозирования временных рядов. Финансы и статистика. 2003, главы 1,4,5,7.
# - Магнус Я.Р., Катышев П.К., Пересецкий А.А. Эконометрика. Начальный курс., глава 11
#
# **Оформление дз**:
# - Присылайте выполненное задание на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2017_Aut_fall <номер_группы> <фамилия>``, к примеру -- ``ML2017_Aut_fall 401 ivanov``
# - Выполненное дз сохраните в файл ``<фамилия>_<группа>_task<номер>.ipnb``, к примеру -- ``ivanov_401_task1.ipnb``
#
# **Вопросы**:
# - Присылайте вопросы на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2017_Aut_fall Question <Содержание вопроса>``
#
# --------
# - **PS1**: Мы используем автоматические фильтры, и просто не найдем ваше дз, если вы не аккуратно его подпишите.
# - **PS2**: Напоминаем, что дедлайны жесткие, письма пришедшие после автоматически удаляются =( чтобы соблазна не было

# %% [markdown]
# <h1 align="center">Check Questions (15%)</h1>

# %% [markdown]
# Ответе на вопросы своими словами (загугленный материал надо пересказать), ответ обоснуйте (напишите и ОБЪЯСНИТЕ формулки если потребуется), если не выходит, то вернитесь к лекции дополнительным материалам:
#
# **Вопрос 1**: Опишите, как изменяется адаптивная способность алгоритма ЭСС при изменении параметра $\alpha$ от 0 до 1.
#
# При альфа близких единицах последние значения получают наибольший вес и при очень близких значениях получится просто смещенный исходный ряд, при стремлении альфа к 0 значение предсказание будет почти константой (равной первому значению)
#
# **Вопрос 2**: Каким следует выбрать параметр сглаживания тренда $\alpha_2$ в модели Хольта (линейный тренд) в случае, когда вы предсказываете временной ряд 1) с плавно меняющимя трендом; 2) стохастически меняющися трендом?
#
# 1)ближе к 0 (меньше 0.3 из лекций) 2)ближе к 1 (влияют в основном последние значения)
#
# **Вопрос 3**: Докажите  эквивалетность формул расчёта (в рекуррентной форме и в форме корректировки прогноза (correction error form) )скрытых компонент временного ряда в модели Тейла-Вейджа (период сезонность обозначается $p$):
# $$l_t = \alpha (y_t - s_{t-p}) + (1-\alpha) (l_{t-1} + b_{t-1} ) \color{red}{=} l_{t-1} + b_{t-1} + \alpha e_t;$$,
#     $$ b_t = \beta (l_{t} - l_{t-1} ) + (1-\beta) b_{t-1} \color{red}{=} b_{t-1} + \alpha\beta e_t;$$,
#     $$ s_t = \gamma (y_t-l_t) + (1-\gamma) s_{t-p} \color{red}{=} s_{t-p} + \gamma(1-\alpha)e_t.$$,
#
# $e_t = y_t - \hat{y}_{t|t-1}$,значит $l_t = \alpha(e_t + l_{t-1} + b_{t-1} + s_{t-p} - s_{t-p}) + (1 - \alpha) (l_{t-1} + b_{t-1}) = \alpha e_t + l_{t-1} + b_{t-1}$, далее в формуле для $b_t$ заменим $l_t$ на полученное выражение: $b_t  = \beta(l_{t-1} + b_{t-1} + \alpha e_t - l_{t-1}) + (1 - \beta) b_{t-1} = b_{t-1} + \alpha \beta e_t$.
# Теперь в выражение для $s_t$ аналогично подставим тождество для $l_t$ и замену $y_t =  e_t + \hat{y}_{t|t-1}$:
# $s_t = \gamma (e_t + l_{t-1} + b_{t-1} + s_{t-p} - l_t) + (1 - \gamma) s_{t-p} = \gamma (e_t + l_{t-1} + b_{t-1} + s_{t-p} - \alpha e_t - l_{t-1} - b_{t-1}) + (1 - \gamma) s_{t-p} = \gamma (1-\alpha) e_t + s_{t-p} $
#
# **Вопрос 4**: Выведите формулу расчёта скрытых компонент в форме корректировки прогноза (correction error form) временного ряда в модели ЭС с линейным затухающим трендом (WS with additive damped trend):
#
# $$\hat{y}_{t+d|t} = l_t + \left(\phi + \phi^2 + \dots + \phi^{d}\right) b_t.$$,
#
# Скрытые компоненты ВР согласно модели в рекуррентной форме записываются:
#     $$ l_{t}       = \alpha y_t + \left(1-\alpha\right) \left(l_{t-1} +\phi b_{t-1}\right),$$,
#     $$ b_t         = \beta \left(l_t - l_{t-1}\right) + \left(1-\beta\right)\phi b_{t-1}.$$
#
#
#
# $e_t = y_t - \hat{y}_{t|t-1}$, получаем что: $l_t = \alpha(e_t + l_{t-1} + \phi b_{t-1}) + (1 - \alpha)(l_{t-1} + \phi b_{t-1}) = \alpha e_t + l_{t-1} + \phi b_{t-1}$, подставив это в выражение для $b_t$ получим: $b_t  = \beta(\alpha e_t + l_{t-1}  + \phi b_{t-1} - l_{t-1}) + (1 - \beta) \phi b_{t-1} = \beta (\alpha e_t + \phi b_{t-1})$
#
# -----------
# PS: Если проверяющий не понял ответ на большинство вопросов, то будет пичалька. Пишите так, чтобы можно было разобраться.

# %% [markdown]
# <h1 align="center"> Practice</h1>
# #  1. reading data (5%)
#
#   * Download data for following data sets
#      - 1) <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv </span>(1 TS of monthly wage in Russia)

# %%
# start with this code
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
from utils import InitExponentialSmoothing, BuildForecast, plotTSForecast
from utils import qualityRMSE, qualityMedianAE, qualityMACAPE, qualitySSE, qualityMSE, qualityMAPE 

# %matplotlib inline


wage = pd.read_csv('monthly-wage.csv', sep=';', decimal='.', index_col=0, parse_dates=True, dayfirst=True)

# Put your code below
wage.plot(figsize=(15,5))

# %% [markdown]
# # 2. Build the Forecast with  IES (5%)
#
# You need to apply IES model (see seminar 1) for the TS <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv</span>.
#
# Forecast delay $h=1$ for all point in this task.
#
#
# * 0) Forecast Wage TS with SES $\alpha=.1$.
# * 1) Find the best param $\alpha$ of SES for data period from 09.1998 to 01.2015. Is the optimal value close to 0 or 1? (You
# can choose any loss function above).
# * 2) Draw the forecast that correspond to IES with optimial value $\alpha$ (use time steps from 09.1998 to 01.2017.)
#      Conclude whether IES can be used for this TS? If can not than explain why.
# * 3) Calculate loss of the forecast of TS in [02.2015, 01.2017]. (You can choose any Loss function from seminar 1).

# %% [markdown]
# ## 1) Search for the optimal $\alpha$

# %%
ALPHA = np.linspace(0, 1, 200)
ESParamsArray = [{'alpha':alpha, 'AdaptationPeriod':5} for alpha in ALPHA]
# в utils.py неправильно был явно написан wage вместо ts
FRC_WAGE = BuildForecast(h=1, ts=wage.loc['1998.09.01' : '2015.01.01'], AlgName='InitExponentialSmoothing', AlgTitle='IES', 
                         ParamsArray=ESParamsArray)

# %%
# compare ES parameters
QualityStr = pd.DataFrame(index = wage.columns, columns = FRC_WAGE.keys())

ix = wage.loc['1998.09.01' : '2015.01.01'].index
for param_cntr in sorted(QualityStr.columns):
    frc_wage = FRC_WAGE[param_cntr]
    QualityStr[param_cntr],_ = qualityMACAPE(wage.loc[ix], frc_wage.loc[ix])

QualityStr[QualityStr.columns].mean().sort_values()
# Out:
# IES {'alpha': 0.36180904522613067, 'AdaptationPeriod': 5}      0.055963
# IES {'alpha': 0.35678391959798994, 'AdaptationPeriod': 5}      0.055963
# IES {'alpha': 0.35175879396984927, 'AdaptationPeriod': 5}      0.055966
# IES {'alpha': 0.36683417085427134, 'AdaptationPeriod': 5}      0.055968
# IES {'alpha': 0.34673366834170855, 'AdaptationPeriod': 5}      0.055972
# IES {'alpha': 0.37185929648241206, 'AdaptationPeriod': 5}      0.055979
# IES {'alpha': 0.34170854271356782, 'AdaptationPeriod': 5}      0.055980
# IES {'alpha': 0.37688442211055279, 'AdaptationPeriod': 5}      0.055993
# IES {'alpha': 0.33668341708542715, 'AdaptationPeriod': 5}      0.056003
# IES {'alpha': 0.38190954773869346, 'AdaptationPeriod': 5}      0.056009
# IES {'alpha': 0.38693467336683418, 'AdaptationPeriod': 5}      0.056027
# IES {'alpha': 0.33165829145728642, 'AdaptationPeriod': 5}      0.056037
# IES {'alpha': 0.39195979899497491, 'AdaptationPeriod': 5}      0.056046
# IES {'alpha': 0.39698492462311558, 'AdaptationPeriod': 5}      0.056067
# IES {'alpha': 0.32663316582914576, 'AdaptationPeriod': 5}      0.056084
# IES {'alpha': 0.4020100502512563, 'AdaptationPeriod': 5}       0.056092
# IES {'alpha': 0.40703517587939697, 'AdaptationPeriod': 5}      0.056119
# IES {'alpha': 0.32160804020100503, 'AdaptationPeriod': 5}      0.056135
# IES {'alpha': 0.4120603015075377, 'AdaptationPeriod': 5}       0.056147
# IES {'alpha': 0.41708542713567842, 'AdaptationPeriod': 5}      0.056186
# IES {'alpha': 0.3165829145728643, 'AdaptationPeriod': 5}       0.056191
# IES {'alpha': 0.42211055276381909, 'AdaptationPeriod': 5}      0.056240
# IES {'alpha': 0.31155778894472363, 'AdaptationPeriod': 5}      0.056254
# IES {'alpha': 0.42713567839195982, 'AdaptationPeriod': 5}      0.056296
# IES {'alpha': 0.30653266331658291, 'AdaptationPeriod': 5}      0.056324
# IES {'alpha': 0.43216080402010049, 'AdaptationPeriod': 5}      0.056355
# IES {'alpha': 0.30150753768844224, 'AdaptationPeriod': 5}      0.056404
# IES {'alpha': 0.43718592964824121, 'AdaptationPeriod': 5}      0.056415
# IES {'alpha': 0.44221105527638194, 'AdaptationPeriod': 5}      0.056477
# IES {'alpha': 0.29648241206030151, 'AdaptationPeriod': 5}      0.056494
#                                                                  ...
# IES {'alpha': 0.14572864321608039, 'AdaptationPeriod': 5}      0.067114
# IES {'alpha': 0.1407035175879397, 'AdaptationPeriod': 5}       0.068154
# IES {'alpha': 0.135678391959799, 'AdaptationPeriod': 5}        0.069277
# IES {'alpha': 0.1306532663316583, 'AdaptationPeriod': 5}       0.070509
# IES {'alpha': 0.12562814070351758, 'AdaptationPeriod': 5}      0.071877
# IES {'alpha': 0.12060301507537688, 'AdaptationPeriod': 5}      0.073390
# IES {'alpha': 0.11557788944723618, 'AdaptationPeriod': 5}      0.075132
# IES {'alpha': 0.11055276381909548, 'AdaptationPeriod': 5}      0.077101
# IES {'alpha': 0.10552763819095477, 'AdaptationPeriod': 5}      0.079282
# IES {'alpha': 0.10050251256281408, 'AdaptationPeriod': 5}      0.081752
# IES {'alpha': 0.095477386934673364, 'AdaptationPeriod': 5}     0.084528
# IES {'alpha': 0.090452261306532666, 'AdaptationPeriod': 5}     0.087592
# IES {'alpha': 0.085427135678391955, 'AdaptationPeriod': 5}     0.091064
# IES {'alpha': 0.080402010050251257, 'AdaptationPeriod': 5}     0.094933
# IES {'alpha': 0.07537688442211056, 'AdaptationPeriod': 5}      0.099277
# IES {'alpha': 0.070351758793969849, 'AdaptationPeriod': 5}     0.104325
# IES {'alpha': 0.065326633165829151, 'AdaptationPeriod': 5}     0.110225
# IES {'alpha': 0.06030150753768844, 'AdaptationPeriod': 5}      0.117160
# IES {'alpha': 0.055276381909547742, 'AdaptationPeriod': 5}     0.125388
# IES {'alpha': 0.050251256281407038, 'AdaptationPeriod': 5}     0.135310
# IES {'alpha': 0.045226130653266333, 'AdaptationPeriod': 5}     0.147206
# IES {'alpha': 0.040201005025125629, 'AdaptationPeriod': 5}     0.161546
# IES {'alpha': 0.035175879396984924, 'AdaptationPeriod': 5}     0.179418
# IES {'alpha': 0.03015075376884422, 'AdaptationPeriod': 5}      0.201892
# IES {'alpha': 0.025125628140703519, 'AdaptationPeriod': 5}     0.230791
# IES {'alpha': 0.020100502512562814, 'AdaptationPeriod': 5}     0.269506
# IES {'alpha': 0.01507537688442211, 'AdaptationPeriod': 5}      0.323317
# IES {'alpha': 0.010050251256281407, 'AdaptationPeriod': 5}     0.402013
# IES {'alpha': 0.0050251256281407036, 'AdaptationPeriod': 5}    0.526315
# IES {'alpha': 0.0, 'AdaptationPeriod': 5}                      0.749117
# Length: 200, dtype: float64

# %% [markdown]
# ### best alpha ~0,36

# %% [markdown]
# ## 2) draw the forecast with optimial value $\alpha $

# %%
ALPHA = [.36]
ESParamsArray = [{'alpha':alpha, 'AdaptationPeriod':5} for alpha in ALPHA]
# в utils.py неправильно был явно написан wage вместо ts
FRC_WAGE = BuildForecast(h=1, ts=wage.loc['1998.09.01' : '2017.01.01'], AlgName='InitExponentialSmoothing', AlgTitle='IES', 
                         ParamsArray=ESParamsArray)

# %%
# compare ES parameters
QualityStr = pd.DataFrame(index = wage.columns, columns = FRC_WAGE.keys())

ix = wage.loc['1998.09.01' : '2017.01.01'].index
for param_cntr in sorted(QualityStr.columns):
    frc_wage = FRC_WAGE[param_cntr]
    QualityStr[param_cntr],_ = qualityMACAPE(wage.loc[ix], frc_wage.loc[ix])

# %%
import matplotlib.pyplot as plt
algName = QualityStr[QualityStr.columns].mean().sort_values().index[0]
plotTSForecast(wage.loc['1998.09.01' : '2017.01.01'], FRC_WAGE[algName].loc['1998.09.01' : '2017.01.01']
               , ts_num=0, alg_title=algName)
plt.show()

plotTSForecast(wage.loc['2015.02.01' : '2017.01.01'], 
               FRC_WAGE[algName].loc['2015.02.01' : '2017.01.01'],
               ts_num=0, alg_title=algName)

# %% [markdown]
# ### Question
# * Does SES follow to the TS components?
#
# ### Answer
# * It doesn't, because model can't keep up with the pace of TS growth + TS has a clear upward linear trend and sort of seasonality.

# %% [markdown]
# ## 3) Calculate loss of the forecast of TS in [02.2015, 01.2017]

# %%
qualityMACAPE(wage.loc['2015.02.01' : '2017.01.01'], FRC_WAGE[algName].loc['2015.02.01' : '2017.01.01'])[0]
# Out:
# Real wage    0.06218
# dtype: float64

# %% [markdown]
# # 3. Winters model for Additive Seasonality (25%)
# You need to realize ES model for TS with additive seasonality and then use it for forecasting real TS <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv</span>.
#
# Forecast delay $h=1$ for all point in this task.
#
# * 1) Realize Winters model for Seasonal TS
# * 2) Find optimal params $\alpha$ (smoothing of level) and $\gamma$ (smoothing of seasonality) (use data from 09.1998 to 01.2015).(Loss function should be the same as in task 2.)
# * 3) Draw the forecast that correspond optimal values $\alpha$ and $\gamma$ (data from 09.1998 to 01.2017).
# * 4) Calculate accuracy of the forecast of TS in [02.2015, 01.2017] (Loss function should be the same as in task 2.). Compare it with accuracy of IES: is it better?
# * 5) Conclude whether Winter's ES can be used for this TS?

# %%
# Start with this code
###################### Winters Exponential Smoothing #########################
# x <array Tx1>- time series, 
# h <scalar> - forecasting delay
# Params <dict> - dictionary with 
#    alpha <scalar in [0,1]> - smoothing parameter
#    delts <scalar in [0,1]> - seasonality smoothing parameter

def WintersExponentialSmoothing(x, h, Params):
    T = len(x)
    alpha = Params['alpha']
    delta = Params['delta']
    p = Params['seasonality_period']
    
    FORECAST = [np.NaN] * (T + h)
    
    s = [np.NaN] * T
    
    # set cool init values for 1st season from wiki (triple exp. smoothing)
    N = int(T / p)
    A = np.zeros(N)
    for j in range(N):
        A[j] = np.sum([x[p*j + i] for i in range(p)])
    A /= p    
    
    for t in range(p):
        s[t] = (np.array(x[t:p*N:p]) / A).sum() / N
    
    l = x[p]
    for t in range(p, T):
        if not math.isnan(x[t]):           
            l_prev = l 
            l =  alpha * (x[t] - s[t-p]) + (1 - alpha) * l
            s[t] = delta * (x[t] - l_prev) + (1 - delta) * s[t-p]
            
        FORECAST[t + h] = l + s[t - p + h%p]
    return FORECAST

def TheilWageExponentialSmoothing(x, h, Params):
    T = len(x)
    alpha = Params['alpha']
    beta = Params['beta']
    gamma = Params['gamma']
    p = Params['seasonality_period']
    
    FORECAST = [np.NaN] * (T + h)
    
    s = [np.NaN] * T
    b = (np.sum(x[p:2*p]) - np.sum(x[:p])) / p ** 2
    
    N = int(T / p)
    A = np.zeros(N)
    for j in range(N):
        A[j] = np.sum([x[p*j + i] for i in range(p)])
    A /= p    
    
    for t in range(p):
        s[t] = (np.array(x[t:p*N:p]) / A).sum() / N
    
    l = x[p]
    for t in range(p, T):
        if not math.isnan(x[t]):           
            l_prev = l 
            l = alpha * (x[t] - s[t-p]) + (1 - alpha) * (l + b)
            b = beta * (l - l_prev) + (1 - beta) * b
            s[t] = gamma * (x[t] - l) + (1 - gamma) * s[t-p]
            
        FORECAST[t + h] = l + h * b + s[t - p + h%p]
    return FORECAST

def MultiWintersExponentialSmoothing(x, h, Params):
    T = len(x)
    alpha = Params['alpha']
    gamma = Params['gamma']
    p = Params['seasonality_period']
    
    FORECAST = [np.NaN] * (T + h)
    
    s = [np.NaN] * T
    
    # set cool init values for 1st season from wiki (triple exp. smoothing)
    N = int(T / p)
    A = np.zeros(N)
    for j in range(N):
        A[j] = np.sum([x[p*j + i] for i in range(p)])
    A /= p    
    
    for t in range(p):
        s[t] = (np.array(x[t:p*N:p]) / A).sum() / N
    
    l = x[p]
    for t in range(p, T):
        if not math.isnan(x[t]):           
            l_prev = l 
            l =  alpha * (x[t] / s[t-p]) + (1 - alpha) * l
            s[t] = gamma * (x[t] / l_prev) + (1 - gamma) * s[t-p]
            
        FORECAST[t + h] = l * s[t - p + h%p]
    return FORECAST

def plotTSForecast(ts, frc_ts, ts_num=0, alg_title=''):
	frc_ts.columns = ts.columns+'; '+alg_title
	ts[ts.columns[0]].plot(style='b', linewidth=1.0, marker='o')
	ax = frc_ts[frc_ts.columns[0]].plot(style='r-^', figsize=(15,5), linewidth=1.0)
	plt.xlabel('Time ticks')
	plt.ylabel('TS values')
	plt.legend()
	return ax

def BuildForecast(h, ts, AlgName, AlgTitle, ParamsArray, step='D'):
	FRC_TS = dict()
	for p in ParamsArray:
		frc_horizon = pd.date_range(ts.index[-1], periods=h+1, freq=step)[1:]
		frc_ts = pd.DataFrame(index = ts.index.append(frc_horizon), columns = ts.columns)
		
		for cntr in ts.columns:
			frc_ts[cntr] = eval(AlgName)(ts[cntr], h, p)
		
#         frc_ts.columns = frc_ts.columns+('%s %s' % (AlgTitle, p))
		FRC_TS['%s %s' % (AlgTitle, p)] = frc_ts
	return FRC_TS

# %%
import math
ALPHA = np.linspace(0.01,1,100) # season ~ year
WESParamsArray = [{'alpha':alpha, 'delta':gamma, 'seasonality_period':12} for (alpha, gamma) in zip(ALPHA, ALPHA)]
FRC_WAGE_W = BuildForecast(h=1, ts=wage, step='M', AlgName='WintersExponentialSmoothing', 
                           AlgTitle='WES',ParamsArray = WESParamsArray)

QualityStr = pd.DataFrame(index=wage.columns, columns=FRC_WAGE_W.keys())

ix = wage.loc['1998-09-01':'2015-01-01'].index
for param_cntr in sorted(QualityStr.columns):
    frc_wage = FRC_WAGE_W[param_cntr]
    QualityStr[param_cntr],_ = qualityMACAPE(wage.loc[ix], frc_wage.loc[ix])

QualityStr[QualityStr.columns].mean().sort_values()
# Out:
# WES {'delta': 0.58000000000000007, 'seasonality_period': 12, 'alpha': 0.58000000000000007}      0.023744
# WES {'delta': 0.58999999999999997, 'seasonality_period': 12, 'alpha': 0.58999999999999997}      0.023747
# WES {'delta': 0.59999999999999998, 'seasonality_period': 12, 'alpha': 0.59999999999999998}      0.023758
# WES {'delta': 0.57000000000000006, 'seasonality_period': 12, 'alpha': 0.57000000000000006}      0.023764
# WES {'delta': 0.60999999999999999, 'seasonality_period': 12, 'alpha': 0.60999999999999999}      0.023795
# WES {'delta': 0.56000000000000005, 'seasonality_period': 12, 'alpha': 0.56000000000000005}      0.023806
# WES {'delta': 0.62, 'seasonality_period': 12, 'alpha': 0.62}                                    0.023854
# WES {'delta': 0.55000000000000004, 'seasonality_period': 12, 'alpha': 0.55000000000000004}      0.023884
# WES {'delta': 0.63, 'seasonality_period': 12, 'alpha': 0.63}                                    0.023937
# WES {'delta': 0.54000000000000004, 'seasonality_period': 12, 'alpha': 0.54000000000000004}      0.023979
# WES {'delta': 0.64000000000000001, 'seasonality_period': 12, 'alpha': 0.64000000000000001}      0.024053
# WES {'delta': 0.53000000000000003, 'seasonality_period': 12, 'alpha': 0.53000000000000003}      0.024128
# WES {'delta': 0.65000000000000002, 'seasonality_period': 12, 'alpha': 0.65000000000000002}      0.024176
# WES {'delta': 0.52000000000000002, 'seasonality_period': 12, 'alpha': 0.52000000000000002}      0.024289
# WES {'delta': 0.66000000000000003, 'seasonality_period': 12, 'alpha': 0.66000000000000003}      0.024309
# WES {'delta': 0.67000000000000004, 'seasonality_period': 12, 'alpha': 0.67000000000000004}      0.024449
# WES {'delta': 0.51000000000000001, 'seasonality_period': 12, 'alpha': 0.51000000000000001}      0.024464
# WES {'delta': 0.68000000000000005, 'seasonality_period': 12, 'alpha': 0.68000000000000005}      0.024607
# WES {'delta': 0.5, 'seasonality_period': 12, 'alpha': 0.5}                                      0.024647
# WES {'delta': 0.69000000000000006, 'seasonality_period': 12, 'alpha': 0.69000000000000006}      0.024796
# WES {'delta': 0.48999999999999999, 'seasonality_period': 12, 'alpha': 0.48999999999999999}      0.024870
# WES {'delta': 0.70000000000000007, 'seasonality_period': 12, 'alpha': 0.70000000000000007}      0.024996
# WES {'delta': 0.48000000000000004, 'seasonality_period': 12, 'alpha': 0.48000000000000004}      0.025119
# WES {'delta': 0.71000000000000008, 'seasonality_period': 12, 'alpha': 0.71000000000000008}      0.025207
# WES {'delta': 0.47000000000000003, 'seasonality_period': 12, 'alpha': 0.47000000000000003}      0.025406
# WES {'delta': 0.71999999999999997, 'seasonality_period': 12, 'alpha': 0.71999999999999997}      0.025430
# WES {'delta': 0.72999999999999998, 'seasonality_period': 12, 'alpha': 0.72999999999999998}      0.025673
# WES {'delta': 0.46000000000000002, 'seasonality_period': 12, 'alpha': 0.46000000000000002}      0.025754
# WES {'delta': 0.73999999999999999, 'seasonality_period': 12, 'alpha': 0.73999999999999999}      0.025963
# WES {'delta': 0.45000000000000001, 'seasonality_period': 12, 'alpha': 0.45000000000000001}      0.026120
#                                                                                                   ...
# WES {'delta': 0.23000000000000001, 'seasonality_period': 12, 'alpha': 0.23000000000000001}      0.044087
# WES {'delta': 0.22, 'seasonality_period': 12, 'alpha': 0.22}                                    0.045679
# WES {'delta': 0.94000000000000006, 'seasonality_period': 12, 'alpha': 0.94000000000000006}      0.046109
# WES {'delta': 0.21000000000000002, 'seasonality_period': 12, 'alpha': 0.21000000000000002}      0.047387
# WES {'delta': 0.20000000000000001, 'seasonality_period': 12, 'alpha': 0.20000000000000001}      0.049218
# WES {'delta': 0.95000000000000007, 'seasonality_period': 12, 'alpha': 0.95000000000000007}      0.050446
# WES {'delta': 0.19, 'seasonality_period': 12, 'alpha': 0.19}                                    0.051176
# WES {'delta': 0.18000000000000002, 'seasonality_period': 12, 'alpha': 0.18000000000000002}      0.053315
# WES {'delta': 0.17000000000000001, 'seasonality_period': 12, 'alpha': 0.17000000000000001}      0.055638
# WES {'delta': 0.96000000000000008, 'seasonality_period': 12, 'alpha': 0.96000000000000008}      0.056031
# WES {'delta': 0.16, 'seasonality_period': 12, 'alpha': 0.16}                                    0.058230
# WES {'delta': 0.15000000000000002, 'seasonality_period': 12, 'alpha': 0.15000000000000002}      0.061091
# WES {'delta': 0.96999999999999997, 'seasonality_period': 12, 'alpha': 0.96999999999999997}      0.063377
# WES {'delta': 0.14000000000000001, 'seasonality_period': 12, 'alpha': 0.14000000000000001}      0.064301
# WES {'delta': 0.13, 'seasonality_period': 12, 'alpha': 0.13}                                    0.067862
# WES {'delta': 0.12, 'seasonality_period': 12, 'alpha': 0.12}                                    0.071815
# WES {'delta': 0.97999999999999998, 'seasonality_period': 12, 'alpha': 0.97999999999999998}      0.073135
# WES {'delta': 0.11, 'seasonality_period': 12, 'alpha': 0.11}                                    0.076339
# WES {'delta': 0.099999999999999992, 'seasonality_period': 12, 'alpha': 0.099999999999999992}    0.081537
# WES {'delta': 0.98999999999999999, 'seasonality_period': 12, 'alpha': 0.98999999999999999}      0.086217
# WES {'delta': 0.089999999999999997, 'seasonality_period': 12, 'alpha': 0.089999999999999997}    0.087628
# WES {'delta': 0.080000000000000002, 'seasonality_period': 12, 'alpha': 0.080000000000000002}    0.095269
# WES {'delta': 1.0, 'seasonality_period': 12, 'alpha': 1.0}                                      0.104680
# WES {'delta': 0.069999999999999993, 'seasonality_period': 12, 'alpha': 0.069999999999999993}    0.104705
# WES {'delta': 0.060000000000000005, 'seasonality_period': 12, 'alpha': 0.060000000000000005}    0.117324
# WES {'delta': 0.050000000000000003, 'seasonality_period': 12, 'alpha': 0.050000000000000003}    0.133940
# WES {'delta': 0.040000000000000001, 'seasonality_period': 12, 'alpha': 0.040000000000000001}    0.157058
# WES {'delta': 0.029999999999999999, 'seasonality_period': 12, 'alpha': 0.029999999999999999}    0.191641
# WES {'delta': 0.02, 'seasonality_period': 12, 'alpha': 0.02}                                    0.245730
# WES {'delta': 0.01, 'seasonality_period': 12, 'alpha': 0.01}                                    0.337804
# Length: 100, dtype: float64

# %%
algName = QualityStr[QualityStr.columns].mean().sort_values().index[0]
plotTSForecast(wage.loc['1998-09-01':'2017-01-01'], FRC_WAGE_W[algName].loc['1998-09-01':'2017-01-01'],
               alg_title='WES')

# %%
qualityMACAPE(wage.loc['2015-02-01':'2017-01-01'], FRC_WAGE_W[algName].loc['2015-02-01':'2017-01-01'])[0]
# Out:
# Real wage    0.017125
# dtype: float64

# %% [markdown]
# #### С добавлением сезонности точность предсказаний улучшилась на порядок

# %% [markdown]
# # 4. Theil-Wage model for TS with linear trend and seasonality (25%)
# You need to realize Theil-Wage model and then use it for forecasting real TS <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv</span>.
#
# Forecast delay $h=1$ for all point in this task.
#
# * 1) Realize Theil-Wage model for
# * 2) Find optimal params $\alpha$ (smoothing of level), $\beta$ (smoothing trend) and $\gamma$ (smoothing of seasonality) (use data from 09.1998 to 01.2015).(Loss function should be the same as in task 2.)
# * 3) Draw forecast with optimal values $\alpha$, $\beta$ and $\gamma$ from 09.1998 to 01.2017.
# * 4) Calculate accuracy of the forecast of TS in [02.2015, 01.2017] (Loss function should be the same as in task 2.). Compare it with accuracy of Winters model: is it better than the last one?
# * \*5) Suggest how can the Theil-Wage model be improved to make accuracy of forecast better?

# %%
ALPHA = np.linspace(0.01,1,200)
TWESParamsArray = [{'alpha':alpha, 'gamma':gamma, 'beta':beta, 'seasonality_period':12}
                  for (alpha, gamma, beta) in zip(ALPHA, ALPHA, ALPHA)]
FRC_WAGE_TW = BuildForecast(h=1, ts=wage, step='M', AlgName='TheilWageExponentialSmoothing', AlgTitle='TWES',
                            ParamsArray = TWESParamsArray)

QualityStr = pd.DataFrame(index=wage.columns, columns=FRC_WAGE_TW.keys())

ix = wage.loc['1998-09-01':'2015-01-01'].index
for param_cntr in sorted(QualityStr.columns):
    frc_wage = FRC_WAGE_TW[param_cntr]
    QualityStr[param_cntr],_ = qualityMACAPE(wage.loc[ix], frc_wage.loc[ix])

QualityStr[QualityStr.columns].mean().sort_values()
# Out:
# TWES {'seasonality_period': 12, 'alpha': 0.3433165829145729, 'beta': 0.3433165829145729, 'gamma': 0.3433165829145729}          0.032355
# TWES {'seasonality_period': 12, 'alpha': 0.34829145728643218, 'beta': 0.34829145728643218, 'gamma': 0.34829145728643218}       0.032362
# TWES {'seasonality_period': 12, 'alpha': 0.33834170854271356, 'beta': 0.33834170854271356, 'gamma': 0.33834170854271356}       0.032384
# TWES {'seasonality_period': 12, 'alpha': 0.35326633165829147, 'beta': 0.35326633165829147, 'gamma': 0.35326633165829147}       0.032408
# TWES {'seasonality_period': 12, 'alpha': 0.35824120603015075, 'beta': 0.35824120603015075, 'gamma': 0.35824120603015075}       0.032484
# TWES {'seasonality_period': 12, 'alpha': 0.33336683417085428, 'beta': 0.33336683417085428, 'gamma': 0.33336683417085428}       0.032508
# TWES {'seasonality_period': 12, 'alpha': 0.36321608040201009, 'beta': 0.36321608040201009, 'gamma': 0.36321608040201009}       0.032596
# TWES {'seasonality_period': 12, 'alpha': 0.32839195979899499, 'beta': 0.32839195979899499, 'gamma': 0.32839195979899499}       0.032676
# TWES {'seasonality_period': 12, 'alpha': 0.36819095477386937, 'beta': 0.36819095477386937, 'gamma': 0.36819095477386937}       0.032762
# TWES {'seasonality_period': 12, 'alpha': 0.32341708542713571, 'beta': 0.32341708542713571, 'gamma': 0.32341708542713571}       0.032883
# TWES {'seasonality_period': 12, 'alpha': 0.37316582914572866, 'beta': 0.37316582914572866, 'gamma': 0.37316582914572866}       0.032994
# TWES {'seasonality_period': 12, 'alpha': 0.31844221105527643, 'beta': 0.31844221105527643, 'gamma': 0.31844221105527643}       0.033110
# TWES {'seasonality_period': 12, 'alpha': 0.37814070351758794, 'beta': 0.37814070351758794, 'gamma': 0.37814070351758794}       0.033250
# TWES {'seasonality_period': 12, 'alpha': 0.31346733668341709, 'beta': 0.31346733668341709, 'gamma': 0.31346733668341709}       0.033360
# TWES {'seasonality_period': 12, 'alpha': 0.38311557788944728, 'beta': 0.38311557788944728, 'gamma': 0.38311557788944728}       0.033562
# TWES {'seasonality_period': 12, 'alpha': 0.3084924623115578, 'beta': 0.3084924623115578, 'gamma': 0.3084924623115578}          0.033621
# TWES {'seasonality_period': 12, 'alpha': 0.30351758793969852, 'beta': 0.30351758793969852, 'gamma': 0.30351758793969852}       0.033882
# TWES {'seasonality_period': 12, 'alpha': 0.38809045226130656, 'beta': 0.38809045226130656, 'gamma': 0.38809045226130656}       0.033962
# TWES {'seasonality_period': 12, 'alpha': 0.29854271356783924, 'beta': 0.29854271356783924, 'gamma': 0.29854271356783924}       0.034146
# TWES {'seasonality_period': 12, 'alpha': 0.39306532663316585, 'beta': 0.39306532663316585, 'gamma': 0.39306532663316585}       0.034401
# TWES {'seasonality_period': 12, 'alpha': 0.2935678391959799, 'beta': 0.2935678391959799, 'gamma': 0.2935678391959799}          0.034412
# TWES {'seasonality_period': 12, 'alpha': 0.28859296482412061, 'beta': 0.28859296482412061, 'gamma': 0.28859296482412061}       0.034690
# TWES {'seasonality_period': 12, 'alpha': 0.39804020100502513, 'beta': 0.39804020100502513, 'gamma': 0.39804020100502513}       0.034929
# TWES {'seasonality_period': 12, 'alpha': 0.28361809045226133, 'beta': 0.28361809045226133, 'gamma': 0.28361809045226133}       0.034959
# TWES {'seasonality_period': 12, 'alpha': 0.27864321608040205, 'beta': 0.27864321608040205, 'gamma': 0.27864321608040205}       0.035237
# TWES {'seasonality_period': 12, 'alpha': 0.40301507537688447, 'beta': 0.40301507537688447, 'gamma': 0.40301507537688447}       0.035499
# TWES {'seasonality_period': 12, 'alpha': 0.27366834170854271, 'beta': 0.27366834170854271, 'gamma': 0.27366834170854271}       0.035545
# TWES {'seasonality_period': 12, 'alpha': 0.26869346733668342, 'beta': 0.26869346733668342, 'gamma': 0.26869346733668342}       0.035862
# TWES {'seasonality_period': 12, 'alpha': 0.40798994974874375, 'beta': 0.40798994974874375, 'gamma': 0.40798994974874375}       0.036135
# TWES {'seasonality_period': 12, 'alpha': 0.26371859296482414, 'beta': 0.26371859296482414, 'gamma': 0.26371859296482414}       0.036294
#                                                                                                                                  ...
# TWES {'seasonality_period': 12, 'alpha': 0.94527638190954777, 'beta': 0.94527638190954777, 'gamma': 0.94527638190954777}       0.070156
# TWES {'seasonality_period': 12, 'alpha': 0.094572864321608038, 'beta': 0.094572864321608038, 'gamma': 0.094572864321608038}    0.070853
# TWES {'seasonality_period': 12, 'alpha': 0.95025125628140705, 'beta': 0.95025125628140705, 'gamma': 0.95025125628140705}       0.071575
# TWES {'seasonality_period': 12, 'alpha': 0.089597989949748741, 'beta': 0.089597989949748741, 'gamma': 0.089597989949748741}    0.072921
# TWES {'seasonality_period': 12, 'alpha': 0.95522613065326634, 'beta': 0.95522613065326634, 'gamma': 0.95522613065326634}       0.073241
# TWES {'seasonality_period': 12, 'alpha': 0.084623115577889443, 'beta': 0.084623115577889443, 'gamma': 0.084623115577889443}    0.074915
# TWES {'seasonality_period': 12, 'alpha': 0.96020100502512562, 'beta': 0.96020100502512562, 'gamma': 0.96020100502512562}       0.075224
# TWES {'seasonality_period': 12, 'alpha': 0.079648241206030146, 'beta': 0.079648241206030146, 'gamma': 0.079648241206030146}    0.076545
# TWES {'seasonality_period': 12, 'alpha': 0.9651758793969849, 'beta': 0.9651758793969849, 'gamma': 0.9651758793969849}          0.077692
# TWES {'seasonality_period': 12, 'alpha': 0.074673366834170848, 'beta': 0.074673366834170848, 'gamma': 0.074673366834170848}    0.077748
# TWES {'seasonality_period': 12, 'alpha': 0.069698492462311551, 'beta': 0.069698492462311551, 'gamma': 0.069698492462311551}    0.078918
# TWES {'seasonality_period': 12, 'alpha': 0.064723618090452267, 'beta': 0.064723618090452267, 'gamma': 0.064723618090452267}    0.080429
# TWES {'seasonality_period': 12, 'alpha': 0.9701507537688443, 'beta': 0.9701507537688443, 'gamma': 0.9701507537688443}          0.081384
# TWES {'seasonality_period': 12, 'alpha': 0.05974874371859297, 'beta': 0.05974874371859297, 'gamma': 0.05974874371859297}       0.082514
# TWES {'seasonality_period': 12, 'alpha': 0.054773869346733672, 'beta': 0.054773869346733672, 'gamma': 0.054773869346733672}    0.085578
# TWES {'seasonality_period': 12, 'alpha': 0.97512562814070358, 'beta': 0.97512562814070358, 'gamma': 0.97512562814070358}       0.085996
# TWES {'seasonality_period': 12, 'alpha': 0.049798994974874375, 'beta': 0.049798994974874375, 'gamma': 0.049798994974874375}    0.090224
# TWES {'seasonality_period': 12, 'alpha': 0.98010050251256287, 'beta': 0.98010050251256287, 'gamma': 0.98010050251256287}       0.091148
# TWES {'seasonality_period': 12, 'alpha': 0.98507537688442215, 'beta': 0.98507537688442215, 'gamma': 0.98507537688442215}       0.096586
# TWES {'seasonality_period': 12, 'alpha': 0.044824120603015077, 'beta': 0.044824120603015077, 'gamma': 0.044824120603015077}    0.097488
# TWES {'seasonality_period': 12, 'alpha': 0.99005025125628143, 'beta': 0.99005025125628143, 'gamma': 0.99005025125628143}       0.102149
# TWES {'seasonality_period': 12, 'alpha': 0.99502512562814072, 'beta': 0.99502512562814072, 'gamma': 0.99502512562814072}       0.108068
# TWES {'seasonality_period': 12, 'alpha': 0.03984924623115578, 'beta': 0.03984924623115578, 'gamma': 0.03984924623115578}       0.109170
# TWES {'seasonality_period': 12, 'alpha': 1.0, 'beta': 1.0, 'gamma': 1.0}                                                       0.114571
# TWES {'seasonality_period': 12, 'alpha': 0.034874371859296482, 'beta': 0.034874371859296482, 'gamma': 0.034874371859296482}    0.126619
# TWES {'seasonality_period': 12, 'alpha': 0.029899497487437185, 'beta': 0.029899497487437185, 'gamma': 0.029899497487437185}    0.151388
# TWES {'seasonality_period': 12, 'alpha': 0.024924623115577887, 'beta': 0.024924623115577887, 'gamma': 0.024924623115577887}    0.187115
# TWES {'seasonality_period': 12, 'alpha': 0.019949748743718593, 'beta': 0.019949748743718593, 'gamma': 0.019949748743718593}    0.250813
# TWES {'seasonality_period': 12, 'alpha': 0.014974874371859296, 'beta': 0.014974874371859296, 'gamma': 0.014974874371859296}    0.391333
# TWES {'seasonality_period': 12, 'alpha': 0.01, 'beta': 0.01, 'gamma': 0.01}                                                    0.674590
# Length: 200, dtype: float64

# %%
algName = QualityStr[QualityStr.columns].mean().sort_values().index[0]
plotTSForecast(wage.loc['1998-09-01':'2017-01-01'], FRC_WAGE_TW[algName].loc['1998-09-01':'2017-01-01'],
               alg_title='TWES')

# %%
qualityMACAPE(wage.loc['2015-02-01':'2017-01-01'], FRC_WAGE_TW[algName].loc['2015-02-01':'2017-01-01'])[0]
# Out:
# Real wage    0.025144
# dtype: float64

# %% [markdown]
# # 5. Non-additive model of ES (25%)
# You need to realize some ES-model that include non-addive component (or multiplicative trend or multiplicative component) and then use it for forecasting real TS <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv</span>.
#
# Forecast delay $h=1$ for all point in this task.
#
# * 1) Realize one of following ES models: ESM(A,M) (t.e. Holt-Winters model), ESM(Ad,M), ESM(M,A), ESM(M,M) model.
# * 2) Find optimal params of the model (use data from 09.1998 to 01.2015). Note: if you choose damped trend model that $\phi$ you can just set it by expert opinion (say $0.98$). (Loss function should be the same as in task 2.)
# * 3) Draw forecast with optimal values of it's params (data from 09.1998 to 01.2017).
# * 4) Calculate accuracy of the forecast of TS in [02.2015, 01.2017] (Loss function should be the same as in task 2.). Compare it with accuracy of Winters model and Theil-Wage model: is it better than the last one?
# * 5) Is it true that multiplicative model are more unstable than additive? Unstable means thet forecast is can diveret

# %%
ALPHA = np.linspace(0.01,1,200)
MWESParamsArray = [{'alpha':alpha, 'gamma':gamma, 'seasonality_period':12}
                  for (alpha, gamma) in zip(ALPHA, ALPHA)]
FRC_WAGE_MW = BuildForecast(h=1, ts=wage, step='M', AlgName='MultiWintersExponentialSmoothing',
                            AlgTitle='MWES',ParamsArray = MWESParamsArray)
QualityStr = pd.DataFrame(index=wage.columns, columns=FRC_WAGE_MW.keys())

ix = wage.loc['1998-09-01':'2015-01-01'].index
for param_cntr in sorted(QualityStr.columns):
    frc_wage = FRC_WAGE_MW[param_cntr]
    QualityStr[param_cntr],_ = qualityMACAPE(wage.loc[ix], frc_wage.loc[ix])

QualityStr[QualityStr.columns].mean().sort_values()
# Out:
# MWES {'seasonality_period': 12, 'alpha': 0.62688442211055284, 'gamma': 0.62688442211055284}      0.022549
# MWES {'seasonality_period': 12, 'alpha': 0.63185929648241212, 'gamma': 0.63185929648241212}      0.022552
# MWES {'seasonality_period': 12, 'alpha': 0.62190954773869345, 'gamma': 0.62190954773869345}      0.022557
# MWES {'seasonality_period': 12, 'alpha': 0.63683417085427141, 'gamma': 0.63683417085427141}      0.022560
# MWES {'seasonality_period': 12, 'alpha': 0.61693467336683416, 'gamma': 0.61693467336683416}      0.022569
# MWES {'seasonality_period': 12, 'alpha': 0.64180904522613069, 'gamma': 0.64180904522613069}      0.022569
# MWES {'seasonality_period': 12, 'alpha': 0.64678391959798998, 'gamma': 0.64678391959798998}      0.022580
# MWES {'seasonality_period': 12, 'alpha': 0.61195979899497488, 'gamma': 0.61195979899497488}      0.022584
# MWES {'seasonality_period': 12, 'alpha': 0.65175879396984926, 'gamma': 0.65175879396984926}      0.022593
# MWES {'seasonality_period': 12, 'alpha': 0.6069849246231156, 'gamma': 0.6069849246231156}        0.022601
# MWES {'seasonality_period': 12, 'alpha': 0.65673366834170854, 'gamma': 0.65673366834170854}      0.022607
# MWES {'seasonality_period': 12, 'alpha': 0.60201005025125631, 'gamma': 0.60201005025125631}      0.022620
# MWES {'seasonality_period': 12, 'alpha': 0.66170854271356783, 'gamma': 0.66170854271356783}      0.022623
# MWES {'seasonality_period': 12, 'alpha': 0.59703517587939703, 'gamma': 0.59703517587939703}      0.022640
# MWES {'seasonality_period': 12, 'alpha': 0.66668341708542711, 'gamma': 0.66668341708542711}      0.022641
# MWES {'seasonality_period': 12, 'alpha': 0.6716582914572865, 'gamma': 0.6716582914572865}        0.022661
# MWES {'seasonality_period': 12, 'alpha': 0.59206030150753775, 'gamma': 0.59206030150753775}      0.022662
# MWES {'seasonality_period': 12, 'alpha': 0.67663316582914579, 'gamma': 0.67663316582914579}      0.022686
# MWES {'seasonality_period': 12, 'alpha': 0.58708542713567846, 'gamma': 0.58708542713567846}      0.022690
# MWES {'seasonality_period': 12, 'alpha': 0.68160804020100507, 'gamma': 0.68160804020100507}      0.022716
# MWES {'seasonality_period': 12, 'alpha': 0.58211055276381907, 'gamma': 0.58211055276381907}      0.022723
# MWES {'seasonality_period': 12, 'alpha': 0.68658291457286436, 'gamma': 0.68658291457286436}      0.022746
# MWES {'seasonality_period': 12, 'alpha': 0.57713567839195978, 'gamma': 0.57713567839195978}      0.022775
# MWES {'seasonality_period': 12, 'alpha': 0.69155778894472364, 'gamma': 0.69155778894472364}      0.022788
# MWES {'seasonality_period': 12, 'alpha': 0.69653266331658292, 'gamma': 0.69653266331658292}      0.022834
# MWES {'seasonality_period': 12, 'alpha': 0.5721608040201005, 'gamma': 0.5721608040201005}        0.022846
# MWES {'seasonality_period': 12, 'alpha': 0.70150753768844221, 'gamma': 0.70150753768844221}      0.022881
# MWES {'seasonality_period': 12, 'alpha': 0.56718592964824122, 'gamma': 0.56718592964824122}      0.022921
# MWES {'seasonality_period': 12, 'alpha': 0.70648241206030149, 'gamma': 0.70648241206030149}      0.022934
# MWES {'seasonality_period': 12, 'alpha': 0.56221105527638193, 'gamma': 0.56221105527638193}      0.022996
#                                                                                                    ...
# MWES {'seasonality_period': 12, 'alpha': 0.12442211055276382, 'gamma': 0.12442211055276382}      0.068821
# MWES {'seasonality_period': 12, 'alpha': 0.97512562814070358, 'gamma': 0.97512562814070358}      0.069712
# MWES {'seasonality_period': 12, 'alpha': 0.11944723618090453, 'gamma': 0.11944723618090453}      0.070855
# MWES {'seasonality_period': 12, 'alpha': 0.11447236180904523, 'gamma': 0.11447236180904523}      0.073075
# MWES {'seasonality_period': 12, 'alpha': 0.98010050251256287, 'gamma': 0.98010050251256287}      0.075129
# MWES {'seasonality_period': 12, 'alpha': 0.10949748743718593, 'gamma': 0.10949748743718593}      0.075434
# MWES {'seasonality_period': 12, 'alpha': 0.10452261306532663, 'gamma': 0.10452261306532663}      0.077978
# MWES {'seasonality_period': 12, 'alpha': 0.099547738693467336, 'gamma': 0.099547738693467336}    0.080779
# MWES {'seasonality_period': 12, 'alpha': 0.98507537688442215, 'gamma': 0.98507537688442215}      0.081374
# MWES {'seasonality_period': 12, 'alpha': 0.094572864321608038, 'gamma': 0.094572864321608038}    0.083911
# MWES {'seasonality_period': 12, 'alpha': 0.089597989949748741, 'gamma': 0.089597989949748741}    0.087304
# MWES {'seasonality_period': 12, 'alpha': 0.99005025125628143, 'gamma': 0.99005025125628143}      0.088708
# MWES {'seasonality_period': 12, 'alpha': 0.084623115577889443, 'gamma': 0.084623115577889443}    0.090982
# MWES {'seasonality_period': 12, 'alpha': 0.079648241206030146, 'gamma': 0.079648241206030146}    0.095041
# MWES {'seasonality_period': 12, 'alpha': 0.99502512562814072, 'gamma': 0.99502512562814072}      0.097296
# MWES {'seasonality_period': 12, 'alpha': 0.074673366834170848, 'gamma': 0.074673366834170848}    0.099536
# MWES {'seasonality_period': 12, 'alpha': 0.069698492462311551, 'gamma': 0.069698492462311551}    0.104588
# MWES {'seasonality_period': 12, 'alpha': 1.0, 'gamma': 1.0}                                      0.107485
# MWES {'seasonality_period': 12, 'alpha': 0.064723618090452267, 'gamma': 0.064723618090452267}    0.110470
# MWES {'seasonality_period': 12, 'alpha': 0.05974874371859297, 'gamma': 0.05974874371859297}      0.117089
# MWES {'seasonality_period': 12, 'alpha': 0.054773869346733672, 'gamma': 0.054773869346733672}    0.124885
# MWES {'seasonality_period': 12, 'alpha': 0.049798994974874375, 'gamma': 0.049798994974874375}    0.134145
# MWES {'seasonality_period': 12, 'alpha': 0.044824120603015077, 'gamma': 0.044824120603015077}    0.144962
# MWES {'seasonality_period': 12, 'alpha': 0.03984924623115578, 'gamma': 0.03984924623115578}      0.157808
# MWES {'seasonality_period': 12, 'alpha': 0.034874371859296482, 'gamma': 0.034874371859296482}    0.173500
# MWES {'seasonality_period': 12, 'alpha': 0.029899497487437185, 'gamma': 0.029899497487437185}    0.192782
# MWES {'seasonality_period': 12, 'alpha': 0.024924623115577887, 'gamma': 0.024924623115577887}    0.216715
# MWES {'seasonality_period': 12, 'alpha': 0.019949748743718593, 'gamma': 0.019949748743718593}    0.246835
# MWES {'seasonality_period': 12, 'alpha': 0.014974874371859296, 'gamma': 0.014974874371859296}    0.286046
# MWES {'seasonality_period': 12, 'alpha': 0.01, 'gamma': 0.01}                                    0.339014
# Length: 200, dtype: float64

# %%
algName = QualityStr[QualityStr.columns].mean().sort_values().index[0]
plotTSForecast(wage.loc['1998-09-01':'2017-01-01'], FRC_WAGE_MW[algName].loc['1998-09-01':'2017-01-01'],
               alg_title='MWES')

# %%
qualityMACAPE(wage.loc['2015-02-01':'2017-01-01'], FRC_WAGE_MW[algName].loc['2015-02-01':'2017-01-01'])[0]
# Out:
# Real wage    0.014088
# dtype: float64
